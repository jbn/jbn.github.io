# %%
# %load_ext itikz

# %% [markdown]
# - Overton window
# - Slippery slope arguments are inertial
# - [belief geometry] Enspird by this euclid. I want to keep writing these and if it resonatse, turn it into a tiny Mediuma is the Message type book.
# - [Where — the comments?]
# - This ignores the maintaince of an equilibrium

# %% [markdown]
# ### What's the difference between me and you?

# %% [markdown]
# As a convenient fiction, assume it is possible to map "I believe" to a point on a finite, one dimensional space. "Taking a position" means placing yourself at the appropriate point.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
#
# \filldraw[color=black, fill=myblue!20!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!20!myred] (7, 0) circle (0.1);
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# For any particular belief, you're not the only one doing so. At any given time, many people are expressing their beliefs. If we happen to observe someone doing so, our brains quickly establish our relative position to theirs, estimating the difference between opinions.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[thick, <->] (3, -0.4) -- (7, -0.4);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
# \node at (5, -0.6) {Difference Between Opinions};
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.5] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred] (3, 0) circle (0.1);
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# These differences have direction in addition to magnitude. With routine evaluations, we are adept at orienting ourselves to this space. We quickly assess how far we would have to move relative to our expression to comply with someone else's.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
#
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred] (3, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred] (3, -0.4) -- (7, -0.4);
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.5] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred] (3, 0) circle (0.1);
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# When people say someone, "defends their position," they're often giving a name to something like inertia. There are a variety of costs — social, psychological, and even institutional — associated with moving from one point to another. It's generally easiest to stay where you are, at least perceptually.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.5] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred] (3, 0) circle (0.1);
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# But — ignoring that individual opinions are noisy samples from complex, latent, and generally conditioned distributions rather than an exact projection of some underlying, isolated belief — people do "change their minds" and their probable, subsequently realized positions.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!30] (3, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!30] (3, -0.4) -- (7, -0.4);
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred] (3, -0.4) -- (2, -0.4);
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# In doing so, the picture becomes dynamic. The moving actor may be aware that they have moved, as well as the direction of their motion. If observed, their counterpart may have a rough idea of the change as well. The "relative to"s multiply.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
#
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, <-, draw=myblue!30!myred] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred] (2, -0.4) -- (7, -0.4);
# \draw[thick, ->, draw=myblue!80!myred] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred] (2, 0.5) -- (3, 0.5);
# \draw[thin, dashed, ->, draw=myblue!80!myred] (2, -0.5) -- (1, -0.5);
# \draw[thin, dashed, ->, draw=myblue!20!myred] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Alice (blue-er) may be aware of where she is now and the direction and cost of traveling back to where she was.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!10] (2, -0.4) -- (7, -0.4);
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.5) -- (3, 0.5);
# \draw[thin, dashed, ->, draw=myblue!80!myred!10] (2, -0.5) -- (1, -0.5);
# \draw[thin, dashed, ->, draw=myblue!20!myred!10] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Bob (red-er) may also be aware of this aspect of Alices change, although he may instead perceive it as a change away from him, rather than in terms of going back.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!10] (2, -0.4) -- (7, -0.4);
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred!10] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred] (2, 0.5) -- (3, 0.5);
# \draw[thin, dashed, ->, draw=myblue!80!myred!10] (2, -0.5) -- (1, -0.5);
# \draw[thin, dashed, ->, draw=myblue!20!myred!10] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Extrapolating, Bob may furthermore assume Alice's probable continuation.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!10] (2, -0.4) -- (7, -0.4);
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred!10] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.5) -- (3, 0.5);
# \draw[thin, dashed, ->, draw=myblue!80!myred!10] (2, -0.5) -- (1, -0.5);
# \draw[thick, dashed, ->, draw=myblue!20!myred] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Alice, too, may perceive a bias to her future changes.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!10] (2, -0.4) -- (7, -0.4);
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred!10] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.5) -- (3, 0.5);
# \draw[thick, dashed, ->, draw=myblue!80!myred] (2, -0.5) -- (1, -0.5);
# \draw[thin, dashed, ->, draw=myblue!20!myred!10] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# The question now becomes: how should this change affect Bob's underlying belief and, by implication, future expressions? If he trusts her, he may assume that the change to her position reflects evidence that she had access to and he did not. Therefore, his change should match hers, at least in direction.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!10] (2, -0.4) -- (7, -0.4);
#
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred!10] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.5) -- (3, 0.5);
# \draw[thick, dashed, ->, draw=myblue!80!myred] (2, -0.5) -- (1, -0.5);
# \draw[thin, dashed, ->, draw=myblue!20!myred!10] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \begin{scope}
#     \begin{scope}
#         \clip(5.8,0.2) rectangle (6.0,-0.2);
#         \filldraw[color=black,fill=myblue!35!myred,opacity=0.5] (6, 0) circle (0.2);
#     \end{scope}
#
#     \begin{scope}
#         \clip(7,0.2) rectangle (7.2,-0.2);
#         \filldraw[color=black,fill=myblue!35!myred,opacity=0.5] (7, 0) circle (0.2);
#     \end{scope}
#
#     \begin{scope}
#         \clip(6,-0.25) rectangle (7, 0.25);
#         \filldraw[color=black,fill=myblue!35!myred,opacity=0.5] (5,-0.2) rectangle (8, 0.2);
#     \end{scope}
#
#     \fill[fill=myblue!35!myred, opacity=0.6] (7, 0) circle (0.1);
#     \filldraw[color=black, fill=myblue!35!myred] (6.5, 0) circle (0.1);
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# But, Bob also knows he and Alice *started in disagreement*. That is, their previous experiences — the ones integrated in their beliefs and observed through expressed opinions — were different, assuming sincerity in expression. Thus, Bob may choose to stay put, discarding Alice's opinion as irrelevant.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
#
# \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (7, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!30!myred] (7, 0) circle (0.1);
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Alternatively, Bob may interpret Alice's movement as evidence of an environmental change that he has yet to observe or directly interrogate. And, given that they initially disagreed, Bob may infer that this evidence calls for reinforced disagreement — movement further away from Alice.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (2, -0.6) -- (2, .6);
# \draw[dotted, color=black] (3, -0.6) -- (3, .6);
# \draw[dotted, color=black] (7, -0.6) -- (7, .6);
#
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.4) -- (7, 0.4);
# \draw[thick, ->, draw=myblue!70!myred!10] (2, -0.4) -- (7, -0.4);
#
#
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!70!myred,opacity=0.1] (3, 0) circle (0.1);
#
# \draw[thick, ->, draw=myblue!80!myred!10] (2, -0.5) -- (3, -0.5);
# \draw[thick, <-, draw=myblue!30!myred!10] (2, 0.5) -- (3, 0.5);
# \draw[thick, dashed, ->, draw=myblue!80!myred] (2, -0.5) -- (1, -0.5);
# \draw[thin, dashed, ->, draw=myblue!20!myred!10] (2, 0.5) -- (1, 0.5);
#
# \filldraw[color=black, fill=myblue!80!myred,opacity=0.5] (2, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!80!myred] (2, 0) circle (0.1);
#
# \begin{scope}[xshift=1cm]
#     \begin{scope}
#         \clip(5.8,0.2) rectangle (6.0,-0.2);
#         \filldraw[color=black,fill=myblue!35!myred,opacity=0.5] (6, 0) circle (0.2);
#     \end{scope}
#
#     \begin{scope}
#         \clip(7,0.2) rectangle (7.2,-0.2);
#         \filldraw[color=black,fill=myblue!35!myred,opacity=0.5] (7, 0) circle (0.2);
#     \end{scope}
#
#     \begin{scope}
#         \clip(6,-0.25) rectangle (7, 0.25);
#         \filldraw[color=black,fill=myblue!35!myred,opacity=0.5] (5,-0.2) rectangle (8, 0.2);
#     \end{scope}
#
#     \fill[fill=myblue!35!myred, opacity=0.6] (6, 0) circle (0.1);
#     \filldraw[color=black, fill=myblue!35!myred] (6.5, 0) circle (0.1);
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# ### Experiential Trust

# %% [markdown]
# The previous illustration also applies when Bob generally distrusts Alice. To illustrate, assume Bob and Alice start out in the same position.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!50!myred] (0, 0) circle (0.1);
#         \node at (-0.3, 0.3) {\scriptsize a};
#     \end{scope}
# \end{scope}
#
# \node at (5, -0.5) {$+$};
# \node at (5, -1.5) {$=$};
#
# \begin{scope}[yshift=-1cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!50!myred] (0, 0) circle (0.1);
#         \node at (0.3, 0.3) {\scriptsize b};
#     \end{scope}
# \end{scope}
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.1);
#         \node at (-0.3, 0.3) {\scriptsize a};
#     \end{scope}
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.1);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.2);
#         \node at (0.3, 0.3) {\scriptsize b};
#     \end{scope}
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Again, Alice moves.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
# \draw [thick, <->] (0, 0) -- (10, 0);
# \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#
# \draw (0, -0.2) -- (0, .2);
# \draw (10, -0.2) -- (10, .2);
#
# \draw[dotted, color=black] (4, -0.6) -- (4, .6);
# \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#
# \begin{scope}[xshift=5cm]
#     \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (0, 0) circle (0.2);
#     \filldraw[color=black, fill=myblue!50!myred] (0, 0) circle (0.1);
#     \node[opacity=0.1] at (-0.3, 0.3) {\tiny a};
# \end{scope}
#
# \draw[thick, ->, draw=myblue!60!myred] (4, -0.5) -- (5, -0.5);
# \draw[thick, <-, draw=myblue!50!myred] (4, 0.5) -- (5, 0.5);
# \draw[thin, dashed, ->, draw=myblue!60!myred] (4, -0.5) -- (3, -0.5);
# \draw[thin, dashed, ->, draw=myblue!50!myred] (4, 0.5) -- (3, 0.5);
#
# \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (4, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!60!myred] (4, 0) circle (0.1);
# \node at (5.3, 0.3) {\scriptsize b};
#
# \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (5, 0) circle (0.2);
# \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (5, 0) circle (0.1);
# \node at (3.7, 0.3) {\scriptsize a};
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Again, Bob must interpret and weight the evidence inherent to his observation of her expression. However, this time, the initial context of agreement is less likely to compel Bob to move away from Alice. Instead, given their initial agreement — and assuming Bob trusts Alice and believes her expression was sincere — his best action is to update his beliefs to match Alice's expression.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \node at (3.7, 0.3) {\scriptsize a};
#     \node at (4.3, 0.3) {\scriptsize b};
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# But, what if Bob doesn't trust Alice? What if his experiences with her in other contexts makes him believe she's an unreliable or even deceptive source of information? In this case, the update rule previously explored seems plausible — rather than ignoring her observable change, he moves to oppose it. Again, distance grows.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize a};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# ### The Problem with Strangers

# %% [markdown]
# Moving away from contexts with familiar counterparts, what happens when Bob encounters someone he does not know, Carol, expressing a particular belief? How does he integrate this information?

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# He may simply ignore the information offered by her expression. After all, if he has no experience with Carol, his assessment of her reliability is bound to be error-prone.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Of course, her expression does communicate *some* information. If Bob generally trusts strangers — assuming both reliability and sincerity — he may move towards Carol, even absent direct experience with her.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         %\filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
# \begin{scope}[xshift=-1cm]
#     \filldraw[rounded corners=3mm, color=black,fill=myblue!35!myred,opacity=0.5] (5.8, -0.2) rectangle (7.2, 0.2);
#
#     \fill[fill=myblue!35!myred, opacity=0.6] (7, 0) circle (0.1);
#     \filldraw[color=black, fill=myblue!35!myred] (6.5, 0) circle (0.1);
#
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Alternatively, if Bob generally distrusts strangers — assumes that they are either unreliable or deceptive or both — he may instead move away from the stranger, Carol.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         %\filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
# \begin{scope}
#     \filldraw[rounded corners=3mm, color=black,fill=myblue!35!myred,opacity=0.5] (5.8, -0.2) rectangle (7.2, 0.2);
#
#
#     %\fill[fill=myblue!35!myred, opacity=0.6] (7, 0) circle (0.1);
#     \filldraw[color=black, fill=myblue!35!myred] (6.5, 0) circle (0.1);
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Yet, as the careful reader may have noticed, Bob is a circle and Carol is a square. While Bob may not personally know with Carol, he may have accumulated a good deal of experience with squares that he can use as a template for evaluation and judgment. That is, he may use an accessible stereotype (here, shape) instead of an unconditional level of trust.

# %% [markdown]
# Consider the addition of another stranger, Ted. Like Carol, Ted is a square. Last week, Bob observed Ted taking a position.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (4.7, 0.3) {\scriptsize t};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Joining the two observations — Ted then, Carol now — by accessible stereotype, Bob may perceive a leftward motion in squares.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (5, 0.3) {\scriptsize t};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
# \begin{scope}[yshift=-4cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node[opacity=0.1] at (5.0, 0.3) {\scriptsize t};
#     \node at (6.3, 0.3) {\scriptsize b};
#
#     \draw[thick, <-, draw=myblue!30!myred] (4, 0.4) -- (6, 0.4);
#     \draw[thick, <-, draw=myblue!30!myred] (4, 0.5) -- (5, 0.5);
#     \draw[thin, dashed, ->, draw=myblue!20!myred] (4, 0.5) -- (3, 0.5);
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Reversing the temporal ordering of his observations, he'd perceive a rightward motion instead.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (5, 0.3) {\scriptsize t};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
# \begin{scope}[yshift=-4cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.1] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.1] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \node at (3.7, 0.3) {\scriptsize c};
#     \node[opacity=0.1] at (5.0, 0.3) {\scriptsize t};
#     \node at (6.3, 0.3) {\scriptsize b};
#
#     \draw[thick, <-, draw=myblue!30!myred] (5, 0.4) -- (6, 0.4);
#     \draw[thick, <-, draw=myblue!30!myred] (5, 0.5) -- (4, 0.5);
#     \draw[thin, dashed, ->, draw=myblue!20!myred] (4, 0.5) -- (6, 0.5);
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# But, in both cases, the perception of motion is noisy at best. Carol may stand in for Tim and vise-versa only if the homogeneity of beliefs induced by "being a square" is absolute, an improbable condition. In all other cases, the motion may be mere illusion — resampled, Tim and Carol may take the same positions previously taken. Thus, if Bob already updated his beliefs in response to his perception of motion and trust/distrust in squares, he risks integration of noise as signal. In turn, this affects how he'll pay attention to, interact with, and learn from squares in the future.

# %% [markdown]
# ## Media Connection

# %% [markdown]
# Of course, we're more than just circles or squares. The very best of moral philosophies — or, at least the ones I prefer — prescribe treating and judging individuals as individuals, rather than on the basis of their traits. Yet, to deny that group identity isn't a vital and necessary aspect of how we interpret and relate to the world — an ever-present and accessible prior — is to engage in willful delusion. Moroever — and contrary to some popular beliefs — stereotyping is not inherently maladaptive. Consider the Platinum Rule: "Treat others the way they want to be treated." This rule is hard to implement for strangers absent some coarse model of their experiences and expectations.
#
# However, stereotypes also represent an exploitable vector for manipulative attack. The challenge is to recognize when stereotypes misguide you and, more critically, when they're used to manipulate you. Consider that human beings don't have just one identity — we have and cultivate many of them. And identities themselves aren't fixed concepts. But, when presented with information for evaluation and judgment, some identities are more accessible and salient than others.
#
# Why?

# %% [markdown]
# Partially, it's a function of biography — the chance (albeit predictable) bad encounter with someone "not like you" that dominates your expectations in a path-dependent way. Something as simple as a competitive context — an omnipresent reality — may compel adoption of a negative stereotype. And reproduction along big structural lines is startlingly easy. There is no easy fix here.

# %% [markdown]
# However, we do see position taking on mass and social media presented as exemplars of some underlying social reality. And, to some degree, it is. But, the incentives for both platforms and content producers select for ever-salient discord. And discord is an easy story to tell.
#
# As a hypothetical, imagine that you're a producer at a news network. There is a strong incentive to inflate both the apparent distance to and relative motion of people with identities underrepresented in your audience. You can do that by carefully (but with incredible ease) selecting which out-group voices to present as adversaries, and in what implicit order.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#     \node at (6.3, 0.3) {\scriptsize b};
#
# \end{scope}
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=3cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#     \node at (6.3, 0.3) {\scriptsize b};
#
# \end{scope}
#
# \begin{scope}[yshift=-4cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=3cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
#     \draw[thick, <-, draw=myblue!30!myred] (3, 0.4) -- (6, 0.4);
#     \draw[thick, <-, draw=myblue!30!myred] (3, 0.5) -- (5, 0.5);
#     \draw[thin, dashed, ->, draw=myblue!20!myred] (4, 0.5) -- (0, 0.5);
#     \node at (6.3, 0.3) {\scriptsize b};
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# But, that's only one side of the manipulative template. Thus far, Bob has been an individual with a circle identity, important only in that it was not a square. But, by presenting circle-aligned commentary, the manipulative media producer can remove Bob's particular position from the equation. They can replace his subjective experiences with their own position, so long as distrust in the out-group exceeds the resulting incredulity for an in-group position too far removed from Bob's. "You are here" gets lost.

# %%
# %%itikz --file-prefix 01-line --as-jinja --temp-dir
# \documentclass[tikz]{standalone}
# \definecolor{myred}{RGB}{213, 94, 0}
# \definecolor{myblue}{RGB}{86, 180, 233}
# \definecolor{mypurple}{RGB}{204, 120, 188}
# \begin{document}
# \begin{tikzpicture}[scale=1.5]
#
# \tikzset{>=stealth}
#
#
#
# \begin{scope}
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=6cm]
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!40!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=gray] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=gray] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=gray] (6, -0.6) -- (6, .6);
#     \node at (6.3, 0.3) {\scriptsize b};
#
# \end{scope}
#
# \begin{scope}[yshift=-2cm]
#     \draw [thick, <->] (0, 0) -- (10, 0);
#     \shade[left color=myblue, right color = myred,opacity=0.5] (0, -0.1) rectangle (10, 0.1);
#     \draw (0, -0.2) -- (0, .2);
#     \draw (10, -0.2) -- (10, .2);
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=7cm]
#         \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (6, -0.6) -- (6, .6);
#
# \end{scope}
#
# \begin{scope}[yshift=-4cm]
#
#
#
#     \begin{scope}[xshift=3cm]
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!60!myred,opacity=0.5] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=5cm]
#         \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (0, 0) circle (0.2);
#         \filldraw[color=black, fill=myblue!30!myred,opacity=0.5] (0, 0) circle (0.1);
#     \end{scope}
#
#     \begin{scope}[xshift=4cm]
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (-0.2, -0.2) rectangle (0.2, 0.2);
#         \filldraw[color=black, fill=myblue!50!myred,opacity=0.1] (-0.1, -0.1) rectangle (0.1, 0.1);
#     \end{scope}
#
#     \draw[dotted, color=black] (4, -0.6) -- (4, .6);
#     \draw[dotted, color=black] (5, -0.6) -- (5, .6);
#     \draw[dotted, color=black] (3, -0.6) -- (3, .6);
#
#     \draw[thick, <-, draw=myblue!30!myred] (3, 0.4) -- (5, 0.4);
#     \draw[thick, <-, draw=myblue!30!myred] (3, 0.5) -- (4, 0.5);
#     \draw[thin, dashed, ->, draw=myblue!20!myred] (4, 0.5) -- (2, 0.5);
#
# \end{scope}
#
#
# \end{tikzpicture}
# \end{document}

# %% [markdown]
# Meanwhile, none of this has accounted for any *direct* evidence about a hugely complex and dynamic world that may and almost certainly has undergone changes. The message conveyed concerns identity. Particular issues are merely the substrate. The misdirection induces pathology — one that is surprisingly difficult to defend against, given our cognitive hardware.
#
# At the level of an individual it may be useful to ask this outline of questions for evaluation,

# %% [markdown]
# - What are you reacting too?
#     - A static position?
#     - An apparent change?
# - Who expresses the opinion you observe?
#     - Is it representative of anyone else?
#     - Does it represent a genuine change?
#     - If so, is it robust or ephemeral?
# - Who *relays* the expression to you?
#     - Do they do so to present changes or positions?
#     - May the have an ulterior reason in either case?

# %% [markdown]
# But, really, for all the exhortation about thinking carefully and exercising media literacy, this isn't a problem subject to piecemeal patches at the individual level. The information environment is fucked because the incentives are wrong. It's all entertainment, with unpredictable major news on world events as tonight's regularly scheduled programming. It's hard to see reality when everything around you is busy telling you dark twisted fantasies.

# %% [markdown]
# ### Reactions
#
# - [Orienting Oneself in Exploitable Vectors: How do I navigate this spectacularized topology?](https://medium.com/@revfutures/orienting-oneself-in-exploitable-vectors-7f22d3ee09f3) by [Giancarlo M. Sandoval](https://twitter.com/homotopical)
